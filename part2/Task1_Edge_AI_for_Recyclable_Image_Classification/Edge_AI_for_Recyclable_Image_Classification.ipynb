# %% [markdown]
# <a href="https://colab.research.google.com/github/terry-kamau/AI-Future-directions/blob/main/Edge_AI_for_Recyclable_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Edge AI Prototype: Recyclable Image Classification**

# %% [markdown]
# # *1:Set up Environment*

# %%
# !pip install tensorflow opencv-python numpy matplotlib
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# # *2:Download dataset (TrashNet)*

# %%
# !wget -O trashnet.zip https://github.com/garythung/trashnet/raw/master/data/dataset-resized.zip
# !unzip -q trashnet.zip -d dataset
# Out:
# --2025-07-06 13:03:54--  https://github.com/garythung/trashnet/raw/master/data/dataset-resized.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip [following]
# --2025-07-06 13:03:54--  https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42834870 (41M) [application/zip]
# Saving to: ‘trashnet.zip’
#
# trashnet.zip        100%[===================>]  40.85M   192MB/s    in 0.2s
#
# 2025-07-06 13:03:55 (192 MB/s) - ‘trashnet.zip’ saved [42834870/42834870]

# %% [markdown]
# # *3:Prepare Data*

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    shear_range=0.2
)

IMG_SIZE = (128, 128)
BATCH_SIZE = 32

train_generator = train_datagen.flow_from_directory(
    'dataset/dataset-resized',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    'dataset/dataset-resized',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Classes: cardboard, glass, metal, paper, plastic, trash
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.

# %% [markdown]
# ## Data Augmentation

# %%
# Define a new ImageDataGenerator for training with more advanced augmentation
train_datagen_augmented = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=40,  # Increased rotation
    width_shift_range=0.2, # Shift horizontally
    height_shift_range=0.2, # Shift vertically
    shear_range=0.2, # Shear transformations
    zoom_range=0.2, # Zoom in/out
    horizontal_flip=True, # Flip horizontally
    fill_mode='nearest' # Fill pixels
)

# Define a separate ImageDataGenerator for validation with only rescaling
val_datagen_no_augmentation = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create new training and validation data generators
train_generator_augmented = train_datagen_augmented.flow_from_directory(
    'dataset/dataset-resized',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator_no_augmentation = val_datagen_no_augmentation.flow_from_directory(
    'dataset/dataset-resized',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

print("New data generators created with advanced augmentation for training.")
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.
# New data generators created with advanced augmentation for training.

# %% [markdown]
# # *4:Hyperparameter Tuning*

# %%
import tensorflow as tf
import time
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

IMG_SIZE = (128, 128)
DATA_DIR = 'dataset/dataset-resized'
LEARNING_RATE = 0.001
BATCH_SIZE = 32
EPOCHS = 8

# ✅ Start Timer
start = time.time()

# 🚀 Create Model
base_model = tf.keras.applications.MobileNetV2(
    input_shape=IMG_SIZE + (3,),
    include_top=False,
    weights='imagenet',
    alpha=0.35
)
base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(6, activation='softmax')
])

optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 🧪 Data Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = train_datagen.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)
val_gen = val_datagen.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# 🎯 Training with Callbacks
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=2, restore_best_weights=True),
    ModelCheckpoint('quick_model.keras', monitor='val_accuracy', save_best_only=True)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# 📈 Accuracy and Duration
val_acc = max(history.history['val_accuracy'])
elapsed = round((time.time() - start)/60, 2)
print(f"\n✅ Final Validation Accuracy: {val_acc:.4f}")
print(f"⏱️ Total Runtime: {elapsed} minutes")
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.4823 - loss: 1.3940
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 35s 416ms/step - accuracy: 0.4838 - loss: 1.3899 - val_accuracy: 0.6342 - val_loss: 0.9500
# Epoch 2/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 23s 359ms/step - accuracy: 0.6979 - loss: 0.8558 - val_accuracy: 0.6779 - val_loss: 0.8752
# Epoch 3/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 377ms/step - accuracy: 0.7430 - loss: 0.7009 - val_accuracy: 0.6899 - val_loss: 0.8576
# Epoch 4/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 24s 379ms/step - accuracy: 0.7804 - loss: 0.6026 - val_accuracy: 0.7097 - val_loss: 0.8187
# Epoch 5/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 388ms/step - accuracy: 0.7848 - loss: 0.5701 - val_accuracy: 0.6998 - val_loss: 0.8368
# Epoch 6/8
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 26s 411ms/step - accuracy: 0.8086 - loss: 0.5379 - val_accuracy: 0.6918 - val_loss: 0.7978
#
# ✅ Final Validation Accuracy: 0.7097
# ⏱️ Total Runtime: 2.95 minutes

# %% [markdown]
# # *5:Build lightweight model (MobileNetV2)*

# %%
# Build lightweight model (MobileNetV2) with fine-tuning

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(128, 128, 3),
    include_top=False,
    weights='imagenet',
    alpha=0.35  # Lightest version
)

# Unfreeze some layers of the base model for fine-tuning
base_model.trainable = True

# Fine-tune from this layer onwards
fine_tune_at = int(len(base_model.layers) * 0.75) # Unfreeze the top 25% of the layers

for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(6, activation='softmax')
])

# Compile the model with a lower learning rate for fine-tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), # Lower learning rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_0.35_128            │ (None, 4, 4, 1280)     │       410,208 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_27     │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 574,950 (2.19 MB)
#  Trainable params: 475,430 (1.81 MB)
#  Non-trainable params: 99,520 (388.75 KB)

# %% [markdown]
# # *6:Train Model*

# %%
history_augmented = model.fit(
    train_generator_augmented,
    epochs=15,
    validation_data=val_generator_no_augmentation,
    verbose=2
)
# Out:
# Epoch 1/15
# 64/64 - 27s - 419ms/step - accuracy: 0.8167 - loss: 0.5109 - val_accuracy: 0.7137 - val_loss: 0.7486
# Epoch 2/15
# 64/64 - 27s - 414ms/step - accuracy: 0.8291 - loss: 0.4716 - val_accuracy: 0.7157 - val_loss: 0.7519
# Epoch 3/15
# 64/64 - 26s - 412ms/step - accuracy: 0.8256 - loss: 0.4777 - val_accuracy: 0.7177 - val_loss: 0.7578
# Epoch 4/15
# 64/64 - 28s - 433ms/step - accuracy: 0.8310 - loss: 0.4956 - val_accuracy: 0.7117 - val_loss: 0.7605
# Epoch 5/15
# 64/64 - 40s - 618ms/step - accuracy: 0.8389 - loss: 0.4726 - val_accuracy: 0.7137 - val_loss: 0.7639
# Epoch 6/15
# 64/64 - 26s - 412ms/step - accuracy: 0.8325 - loss: 0.4735 - val_accuracy: 0.7117 - val_loss: 0.7607
# Epoch 7/15
# 64/64 - 26s - 411ms/step - accuracy: 0.8315 - loss: 0.4855 - val_accuracy: 0.7157 - val_loss: 0.7488
# Epoch 8/15
# 64/64 - 26s - 410ms/step - accuracy: 0.8300 - loss: 0.4814 - val_accuracy: 0.7157 - val_loss: 0.7595
# Epoch 9/15
# 64/64 - 28s - 437ms/step - accuracy: 0.8370 - loss: 0.4648 - val_accuracy: 0.7137 - val_loss: 0.7554
# Epoch 10/15
# 64/64 - 40s - 622ms/step - accuracy: 0.8271 - loss: 0.4752 - val_accuracy: 0.7117 - val_loss: 0.7527
# Epoch 11/15
# 64/64 - 27s - 415ms/step - accuracy: 0.8399 - loss: 0.4594 - val_accuracy: 0.7157 - val_loss: 0.7475
# Epoch 12/15
# 64/64 - 27s - 423ms/step - accuracy: 0.8310 - loss: 0.4652 - val_accuracy: 0.7197 - val_loss: 0.7483
# Epoch 13/15
# 64/64 - 27s - 421ms/step - accuracy: 0.8320 - loss: 0.4586 - val_accuracy: 0.7177 - val_loss: 0.7478
# Epoch 14/15
# 64/64 - 28s - 435ms/step - accuracy: 0.8379 - loss: 0.4610 - val_accuracy: 0.7177 - val_loss: 0.7507
# Epoch 15/15
# 64/64 - 28s - 436ms/step - accuracy: 0.8434 - loss: 0.4578 - val_accuracy: 0.7177 - val_loss: 0.7492

# %% [markdown]
# # *7:Convert to TF*Lite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Quantization
tflite_model = converter.convert()

with open('recyclable_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpro9fmgom'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='keras_tensor_4474')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   133007782063632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782242512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782233296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782062480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782064016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782244432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782246736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782234832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782248272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782245584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782245200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782247504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782244816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007782246352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806206352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806216144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806214992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806210576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806209424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806204816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806202512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806207504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806212112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806208464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806212496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806212688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806216528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806214800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806213264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806214032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806210960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780167504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780166736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007806217104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780163088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780160784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780163280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780162896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780162512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780166544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780156176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780159440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780157136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780167120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780153488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780153296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780155600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780151760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780164432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780164624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779598352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779595664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007780154640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779597200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779599888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779602192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779598160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779596816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779604496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779606032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779604880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779602000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779596048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779606224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779604304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779610064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779609296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779596240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779607568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898051408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898054672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779603920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898051792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898065232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898063888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898066384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898063504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898052176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898054096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898053328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898060624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898055632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898051984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898057360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898058704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898061776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898064272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898062544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898053136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002597264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007898055056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002596880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002604944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002609936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002608400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002599952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002605712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002604560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002594576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002605904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002600720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002976592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002981584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002983504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002986576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002976976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003386768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003389456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003394448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003392912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003382928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003390224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003396752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003392144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003390416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003384464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009003385616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001673168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001675856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002076816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002077968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009001664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002081808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002077584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002084496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002085264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002070864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002071056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002079504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008985544592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008985550928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009002084112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008985539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008985541520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008981658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008981665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008985547856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008981658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008981660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008979809232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008979817488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008981662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008981659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008979811152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008978080400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008978070800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008979806160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008979814608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008978073872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009127845008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009127836176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008978069648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008978069264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009127837712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009127838096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129497296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009127841552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009127836944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129493840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129490768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129190800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129490000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129500944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129183504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129178704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129420368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129190224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129187344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129417296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129409040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129410768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009129409616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009126842128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009126843664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009126841552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009126845200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133009126845392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708167504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708169424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708161168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708165968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708171920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708163088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474993488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708160400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008708161552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474983504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474981008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008474983888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472140560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472141712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472145168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472134416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472130960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472133264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472133840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472131728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472144016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008472138256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470289744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470280912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470294352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470283600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470280528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466537424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470292048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470281104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466532240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133007779600656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470285904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466539728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470282448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008470293968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466527824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466528208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466541264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466529168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466539344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703990736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466535504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008466537040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703994576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703994960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703993808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703992272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703984400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703983632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008866272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703979792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008703989968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008866276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008866274832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008866273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133008727944336: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# # *8:Test TFLite mode*l

# %%
interpreter = tf.lite.Interpreter(model_content=tflite_model)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test accuracy
correct = 0
total = 0

# Iterate through the validation dataset one image at a time
for i in range(len(val_generator.filenames)):
    img_path = f'{val_generator.directory}/{val_generator.filenames[i]}'
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array / 255.0, axis=0)  # Add batch dimension and rescale

    # Get the true label
    true_label = val_generator.classes[i]
    true_label_one_hot = tf.keras.utils.to_categorical(true_label, num_classes=len(val_generator.class_indices))


    interpreter.set_tensor(input_details[0]['index'], img_array.astype(input_details[0]['dtype']))
    interpreter.invoke()
    pred = interpreter.get_tensor(output_details[0]['index'])

    correct += np.argmax(pred) == np.argmax(true_label_one_hot)
    total += 1


print(f"TFLite Test Accuracy: {correct/total:.2%}")
# Out:
# TFLite Test Accuracy: 70.38%

# %%
# Save class labels to a file
class_labels = list(train_generator.class_indices.keys())
with open('class_labels.json', 'w') as f:
    json.dump(class_labels, f)

print("Class labels saved to class_labels.json")
print(f"Class labels: {class_labels}")
# Out:
# Class labels saved to class_labels.json
# Class labels: ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# # *9:Visualizing the Predictions*

# %%
# Visualize some predictions
import matplotlib.pyplot as plt
import random

class_labels = list(train_generator.class_indices.keys())

# Get a few random images from the validation set
num_images_to_show = 5
random_indices = random.sample(range(len(val_generator.filenames)), num_images_to_show)

plt.figure(figsize=(15, 10))

for i, index in enumerate(random_indices):
    img_path = f'{val_generator.directory}/{val_generator.filenames[index]}'
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array / 255.0, axis=0)  # Add batch dimension and rescale

    # Get the true label
    true_label_index = val_generator.classes[index]
    true_label = class_labels[true_label_index]

    # Run inference with TFLite model
    interpreter.set_tensor(input_details[0]['index'], img_array.astype(input_details[0]['dtype']))
    interpreter.invoke()
    predictions = interpreter.get_tensor(output_details[0]['index'])
    predicted_class_index = np.argmax(predictions)
    predicted_label = class_labels[predicted_class_index]

    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(img)
    plt.title(f"True: {true_label}\nPred: {predicted_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyze misclassifications
#
# ### Subtask:
# Look at the images that the model is getting wrong to understand if there are any patterns or specific classes that are more difficult for the model.

# %%
misclassified_images = []
class_labels = list(val_generator.class_indices.keys())

for i in range(len(val_generator.filenames)):
    img_path = f'{val_generator.directory}/{val_generator.filenames[i]}'
    true_label_index = val_generator.classes[i]
    true_label = class_labels[true_label_index]

    # Load and preprocess the image for TFLite inference
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array / 255.0, axis=0).astype(input_details[0]['dtype']) # Add batch dimension and rescale

    # Run inference with TFLite model
    interpreter.set_tensor(input_details[0]['index'], img_array)
    interpreter.invoke()
    predictions = interpreter.get_tensor(output_details[0]['index'])
    predicted_class_index = np.argmax(predictions)
    predicted_label = class_labels[predicted_class_index]

    if predicted_label != true_label:
        misclassified_images.append({
            'image_path': img_path,
            'true_label': true_label,
            'predicted_label': predicted_label
        })

print(f"Found {len(misclassified_images)} misclassified images.")
# Out:
# Found 149 misclassified images.

# %% [markdown]
# Visualize a sample of the misclassified images to observe patterns in the errors.

# %%
import random

# Visualize a sample of misclassified images
num_images_to_show = min(10, len(misclassified_images)) # Show up to 10 misclassified images
random_misclassified_indices = random.sample(range(len(misclassified_images)), num_images_to_show)

plt.figure(figsize=(15, num_images_to_show * 2))

for i, index in enumerate(random_misclassified_indices):
    misclassified_info = misclassified_images[index]
    img_path = misclassified_info['image_path']
    true_label = misclassified_info['true_label']
    predicted_label = misclassified_info['predicted_label']

    img = tf.keras.preprocessing.image.load_img(img_path)

    plt.subplot(num_images_to_show, 1, i + 1)
    plt.imshow(img)
    plt.title(f"True: {true_label}, Predicted: {predicted_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Analyze the visualized misclassifications and summarize the types of misclassifications observed and hypothesize potential reasons for these errors based on the sample images.

# %%
print("Analysis of Misclassifications:")
print("- The model seems to confuse similar-looking materials, e.g., cardboard and paper, or different types of plastic.")
print("- Images with complex backgrounds or multiple objects might be challenging for the model.")
print("- Lighting conditions and image quality could also contribute to misclassifications.")
print("- Some classes might have more visual variation than others, leading to more errors in those classes.")
# Out:
# Analysis of Misclassifications:
# - The model seems to confuse similar-looking materials, e.g., cardboard and paper, or different types of plastic.
# - Images with complex backgrounds or multiple objects might be challenging for the model.
# - Lighting conditions and image quality could also contribute to misclassifications.
# - Some classes might have more visual variation than others, leading to more errors in those classes.

# %% [markdown]
# ## Visualize Correct Predictions

# %%
# Visualize some correct predictions
import matplotlib.pyplot as plt
import random

class_labels = list(val_generator.class_indices.keys())
correctly_classified_images = []

# Find correctly classified images
for i in range(len(val_generator.filenames)):
    img_path = f'{val_generator.directory}/{val_generator.filenames[i]}'
    true_label_index = val_generator.classes[i]
    true_label = class_labels[true_label_index]

    # Load and preprocess the image for TFLite inference
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array / 255.0, axis=0).astype(input_details[0]['dtype']) # Add batch dimension and rescale

    # Run inference with TFLite model
    interpreter.set_tensor(input_details[0]['index'], img_array)
    interpreter.invoke()
    predictions = interpreter.get_tensor(output_details[0]['index'])
    predicted_class_index = np.argmax(predictions)
    predicted_label = class_labels[predicted_class_index]

    if predicted_label == true_label:
        correctly_classified_images.append({
            'image_path': img_path,
            'true_label': true_label,
            'predicted_label': predicted_label
        })

print(f"Found {len(correctly_classified_images)} correctly classified images.")

# Visualize a sample of correctly classified images
num_images_to_show = min(10, len(correctly_classified_images)) # Show up to 10 correctly classified images
if num_images_to_show > 0:
    random_correct_indices = random.sample(range(len(correctly_classified_images)), num_images_to_show)

    plt.figure(figsize=(15, num_images_to_show * 2))

    for i, index in enumerate(random_correct_indices):
        correct_info = correctly_classified_images[index]
        img_path = correct_info['image_path']
        true_label = correct_info['true_label']
        predicted_label = correct_info['predicted_label'] # Should be the same as true_label

        img = tf.keras.preprocessing.image.load_img(img_path)

        plt.subplot(num_images_to_show, 1, i + 1)
        plt.imshow(img)
        plt.title(f"True: {true_label}, Predicted: {predicted_label}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No correctly classified images to show in the sample.")
# Out:
# Found 354 correctly classified images.
